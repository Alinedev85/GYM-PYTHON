# %%
import requests
import pandas as pd

# %%
from io import StringIO

url = "https://repositorio.seade.gov.br/dataset/aacd1b41-25de-4cae-9ae6-526f9417a53b/resource/bbce7c2c-d1ec-4c09-b64c-8d4ed7c2207d/download/econ_comex.csv"

try:

    response = requests.get(url, verify=False)
    response.raise_for_status()

    df = pd.read_csv(StringIO(response.text))


    print("Primeiras linhas do DataFrame:")
    print(df.head())

except requests.exceptions.RequestException as error:
    print(f"Erro ao ler o arquivo .csv: {error}")
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'repositorio.seade.gov.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Primeiras linhas do DataFrame:
#   Cod_IBGE;Localidades;Valor das Exportações (US$ FOB);Valor das Importações (US$ FOB)
# 0                 3500105;Adamantina;20915821;697487
# 1                                 3500204;Adolfo;0;0
# 2                      3500303;Aguaí;137409;32478066
# 3                     3500402;Águas da Prata;0;23864
# 4                  3500501;Águas de Lindóia;0;583748

# %%
print(df.columns)
# Out:
# Index(['Cod_IBGE;Localidades;Valor das Exportações (US$ FOB);Valor das Importações (US$ FOB)'], dtype='object')

# %%
df.sort_values(["Localidades", "Valor das Exportações"], ascending=[False, True]).head()
# Out:
#     Cod_IBGE;Localidades;Valor das Exportações (US$ FOB);Valor das Importações (US$ FOB)  \
# 383                                   3533809;Óleo;0;0
# 16                      3501400;Álvaro de Carvalho;0;0
# 15              3501301;Álvares Machado;3347719;893970
# 14                        3501202;Álvares Florence;0;0
# 6                3500600;Águas de São Pedro;1384;22498
#
#     Cod_IBGE         Localidades Valor das Exportações Valor das Importações
# 383  3533809                Óleo                     0                     0
# 16   3501400  Álvaro de Carvalho                     0                     0
# 15   3501301     Álvares Machado               3347719                893970
# 14   3501202    Álvares Florence                     0                     0
# 6    3500600  Águas de São Pedro                  1384                 22498
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Cod_IBGE;Localidades;Valor das Exportações (US$ FOB);Valor das Importações (US$ FOB)').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Cod_IBGE').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Localidades').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Valor das Exportações').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Cod_IBGE'].value_counts()
#     for x_label, grp in _df_6.groupby('Cod_IBGE;Localidades;Valor das Exportações (US$ FOB);Valor das Importações (US$ FOB)')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Cod_IBGE;Localidades;Valor das Exportações (US$ FOB);Valor das Importações (US$ FOB)')
# _ = plt.ylabel('Cod_IBGE')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Localidades'].value_counts()
#     for x_label, grp in _df_7.groupby('Cod_IBGE')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Cod_IBGE')
# _ = plt.ylabel('Localidades')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Valor das Exportações'].value_counts()
#     for x_label, grp in _df_8.groupby('Localidades')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Localidades')
# _ = plt.ylabel('Valor das Exportações')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Valor das Importações'].value_counts()
#     for x_label, grp in _df_9.groupby('Valor das Exportações')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Valor das Exportações')
# _ = plt.ylabel('Valor das Importações')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['Cod_IBGE;Localidades;Valor das Exportações (US$ FOB);Valor das Importações (US$ FOB)'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='index', y='Cod_IBGE;Localidades;Valor das Exportações (US$ FOB);Valor das Importações (US$ FOB)', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['Cod_IBGE'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='index', y='Cod_IBGE', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['Localidades'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='index', y='Localidades', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['Valor das Exportações'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='index', y='Valor das Exportações', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
